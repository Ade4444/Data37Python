# %%
import pandas as pd

# %%
iris = pd.read_csv("iris.csv")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris = pd.read_csv("iris.csv", sep=",", header="infer")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# iris.to_csv("") with filename

# %% [markdown]
# Using the Iris dataset, do the following:
#
# - Add a rank column to the iris DataFrame, ranking the petal length in an ascending order
# - Find the mean of each column for each species
# - Create a new DataFrame for each of the species separately - should have 3 in total, make sure each index starts at 0
# - Create two final DataFrames: One for the Sepal information, and one for the Petal information. This should be done on the whole dataset so that in each DataFrame we have information about all three species

# %%
iris = iris.sort_values('petal_length') # or ascending=False for descending
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 22            4.6          3.6           1.0          0.2     setosa
# 13            4.3          3.0           1.1          0.1     setosa
# 14            5.8          4.0           1.2          0.2     setosa
# 35            5.0          3.2           1.2          0.2     setosa
# 36            5.5          3.5           1.3          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 131           7.9          3.8           6.4          2.0  virginica
# 105           7.6          3.0           6.6          2.1  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 118           7.7          2.6           6.9          2.3  virginica
#
# [150 rows x 5 columns]

# %%
iris[["sepal_length", "sepal_width", "petal_length", "petal_width"]].mean()
# Out:
# sepal_length    5.843333
# sepal_width     3.054000
# petal_length    3.758667
# petal_width     1.198667
# dtype: float64

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 22            4.6          3.6           1.0          0.2     setosa
# 13            4.3          3.0           1.1          0.1     setosa
# 14            5.8          4.0           1.2          0.2     setosa
# 35            5.0          3.2           1.2          0.2     setosa
# 36            5.5          3.5           1.3          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 131           7.9          3.8           6.4          2.0  virginica
# 105           7.6          3.0           6.6          2.1  virginica
# 117           7.7          3.8           6.7          2.2  virginica
# 122           7.7          2.8           6.7          2.0  virginica
# 118           7.7          2.6           6.9          2.3  virginica
#
# [150 rows x 5 columns]

# %%
se = iris[["sepal_length"]]
se
# Out:
#      sepal_length
# 22            4.6
# 13            4.3
# 14            5.8
# 35            5.0
# 36            5.5
# ..            ...
# 131           7.9
# 105           7.6
# 117           7.7
# 122           7.7
# 118           7.7
#
# [150 rows x 1 columns]

# %%
spec = iris.groupby('species')
spec

# %%
spec.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 22            4.6          3.6           1.0          0.2      setosa
# 13            4.3          3.0           1.1          0.1      setosa
# 14            5.8          4.0           1.2          0.2      setosa
# 35            5.0          3.2           1.2          0.2      setosa
# 36            5.5          3.5           1.3          0.2      setosa
# 98            5.1          2.5           3.0          1.1  versicolor
# 93            5.0          2.3           3.3          1.0  versicolor
# 57            4.9          2.4           3.3          1.0  versicolor
# 60            5.0          2.0           3.5          1.0  versicolor
# 79            5.7          2.6           3.5          1.0  versicolor
# 106           4.9          2.5           4.5          1.7   virginica
# 138           6.0          3.0           4.8          1.8   virginica
# ...

# %%
spec.describe()
# Out:
#            sepal_length                                              \
#                   count   mean       std  min    25%  50%  75%  max
# species
# setosa             50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8
# versicolor         50.0  5.936  0.516171  4.9  5.600  5.9  6.3  7.0
# virginica          50.0  6.588  0.635880  4.9  6.225  6.5  6.9  7.9
#
#            sepal_width         ... petal_length      petal_width         \
#                  count   mean  ...          75%  max       count   mean
# species                        ...
# setosa            50.0  3.418  ...        1.575  1.9        50.0  0.244
# versicolor        50.0  2.770  ...        4.600  5.1        50.0  1.326
# virginica         50.0  2.974  ...        5.875  6.9        50.0  2.026
#
#
#                  std  min  25%  50%  75%  max
# species
# setosa      0.107210  0.1  0.2  0.2  0.3  0.6
# versicolor  0.197753  1.0  1.2  1.3  1.5  1.8
# virginica   0.274650  1.4  1.8  2.0  2.3  2.5
#
# ...

# %%
spec.mean()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.418         1.464        0.244
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %%
iris.groupby("species").mean()
# Out:
#             sepal_length  sepal_width  petal_length  petal_width
# species
# setosa             5.006        3.418         1.464        0.244
# versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %%
setosa = iris[iris["species"] == 'setosa']
virginica = iris[iris["species"] == 'virginica']
versicolor = iris[iris["species"] == 'versicolor']

# %%
spec[spec['iris']
# Out:
#   Input In [25]
#     spec[spec['iris']
#                      ^
# SyntaxError: incomplete input

# %%
sepal = iris[["sepal_length", "sepal_width", "species"]]
petal = iris[["petal_length", "petal_width", "species"]]

# %%
petal
# Out:
#      petal_length  petal_width    species
# 22            1.0          0.2     setosa
# 13            1.1          0.1     setosa
# 14            1.2          0.2     setosa
# 35            1.2          0.2     setosa
# 36            1.3          0.2     setosa
# ..            ...          ...        ...
# 131           6.4          2.0  virginica
# 105           6.6          2.1  virginica
# 117           6.7          2.2  virginica
# 122           6.7          2.0  virginica
# 118           6.9          2.3  virginica
#
# [150 rows x 3 columns]

# %%
pd.merge(sepal, petal, how='inner', right_index=True, left_index=True)
# Out:
#      sepal_length  sepal_width  species_x  petal_length  petal_width  \
# 22            4.6          3.6     setosa           1.0          0.2
# 13            4.3          3.0     setosa           1.1          0.1
# 14            5.8          4.0     setosa           1.2          0.2
# 35            5.0          3.2     setosa           1.2          0.2
# 36            5.5          3.5     setosa           1.3          0.2
# ..            ...          ...        ...           ...          ...
# 131           7.9          3.8  virginica           6.4          2.0
# 105           7.6          3.0  virginica           6.6          2.1
# 117           7.7          3.8  virginica           6.7          2.2
# 122           7.7          2.8  virginica           6.7          2.0
# 118           7.7          2.6  virginica           6.9          2.3
#
#      species_y
# 22      setosa
# 13      setosa
# 14      setosa
# 35      setosa
# 36      setosa
# ..         ...
# 131  virginica
# ...

# %%
import numpy as np

# %%
sepal["sepal_id"] = np.arange(150)
petal["petal_id"] = np.arange(150)
sepal.tail()
# Out:
# C:\Users\adeak\AppData\Local\Temp\ipykernel_13292\2718347242.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sepal["sepal_id"] = np.arange(150)
# C:\Users\adeak\AppData\Local\Temp\ipykernel_13292\2718347242.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   petal["petal_id"] = np.arange(150)
#      sepal_length  sepal_width    species  sepal_id
# 131           7.9          3.8  virginica       145
# 105           7.6          3.0  virginica       146
# ...

# %%
pd.merge(sepal, petal, left_on="sepal_id", right_on="petal_id")
# Out:
#      sepal_length  sepal_width  species_x  sepal_id  petal_length  \
# 0             4.6          3.6     setosa         0           1.0
# 1             4.3          3.0     setosa         1           1.1
# 2             5.8          4.0     setosa         2           1.2
# 3             5.0          3.2     setosa         3           1.2
# 4             5.5          3.5     setosa         4           1.3
# ..            ...          ...        ...       ...           ...
# 145           7.9          3.8  virginica       145           6.4
# 146           7.6          3.0  virginica       146           6.6
# 147           7.7          3.8  virginica       147           6.7
# 148           7.7          2.8  virginica       148           6.7
# 149           7.7          2.6  virginica       149           6.9
#
#      petal_width  species_y  petal_id
# 0            0.2     setosa         0
# 1            0.1     setosa         1
# 2            0.2     setosa         2
# ...

# %%
pd.concat([versicolor, setosa])
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 98           5.1          2.5           3.0          1.1  versicolor
# 93           5.0          2.3           3.3          1.0  versicolor
# 57           4.9          2.4           3.3          1.0  versicolor
# 60           5.0          2.0           3.5          1.0  versicolor
# 79           5.7          2.6           3.5          1.0  versicolor
# ..           ...          ...           ...          ...         ...
# 5            5.4          3.9           1.7          0.4      setosa
# 23           5.1          3.3           1.7          0.5      setosa
# 20           5.4          3.4           1.7          0.2      setosa
# 24           4.8          3.4           1.9          0.2      setosa
# 44           5.1          3.8           1.9          0.4      setosa
#
# [100 rows x 5 columns]

# %%
import seaborn as sns

# %%
flights = sns.load_dataset("flights")

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
flights_pivot = flights.pivot("year", "month", "passengers")
flights_pivot
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201
# 1954   204  188  235  227  234  264  302  293  259  229  203  229
# 1955   242  233  267  269  270  315  364  347  312  274  237  278
# 1956   284  277  317  313  318  374  413  405  355  306  271  306
# 1957   315  301  356  348  355  422  465  467  404  347  305  336
# 1958   340  318  362  348  363  435  491  505  404  359  310  337
# 1959   360  342  406  396  420  472  548  559  463  407  362  405
# 1960   417  391  419  461  472  535  622  606  508  461  390  432

# %%
sns.heatmap(flights_pivot)
# Out:
# <AxesSubplot:xlabel='month', ylabel='year'>

# %%
flights_stack = flights_pivot.stack()
flights_stack
# Out:
# year  month
# 1949  Jan      112
#       Feb      118
#       Mar      132
#       Apr      129
#       May      121
#               ...
# 1960  Aug      606
#       Sep      508
#       Oct      461
#       Nov      390
#       Dec      432
# Length: 144, dtype: int64

# %%
flights_stack[1955, 'Apr']
# Out:
# 269

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'exercise',
#  'flights',
#  'fmri',
#  'gammas',
#  'geyser',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'taxis',
#  'tips',
#  'titanic']
